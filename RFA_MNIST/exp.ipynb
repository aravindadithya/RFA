# %%
import torch
import config as c
from utils import trainer as t
# Out:
# Current Path: /workspaces/RFA

# %%
config = c.get_config(0, run_id="12")
config_rfa = c.get_config(1, run_id="5")

# %%
t.train_network(config_rfa, num_epochs=40)
# Out:
# Initializing Wandb:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/workspaces/RFA/RFA_MNIST/wandb/run-20260303_215735-5</code>
# Resuming run <strong><a href='https://wandb.ai/RFA100/MNIST_RFA/runs/5' target="_blank">FC_Model1_RFA</a></strong> to <a href='https://wandb.ai/RFA100/MNIST_RFA' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/RFA100/MNIST_RFA' target="_blank">https://wandb.ai/RFA100/MNIST_RFA</a>
#  View run at <a href='https://wandb.ai/RFA100/MNIST_RFA/runs/5' target="_blank">https://wandb.ai/RFA100/MNIST_RFA/runs/5</a>
# Collected 30 images for visualization (3 from each of 10 classes).
# Resuming from previous run...
# Best Val Acc so far in the training run: 93.24166666666666
# EPOCH:  131
# Time:  1.8508892059326172
# EPOCH:  132
# Time:  1.7539193630218506
# EPOCH:  133
# Time:  1.5895121097564697
# EPOCH:  134
# ...
