# %%
import torch
import config as c
from utils import trainer as t
# Out:
# Current Path: /workspaces/RFA

# %%
config = c.get_config(0, run_id="3")
config_rfa = c.get_config(1, run_id="4")

# %%
t.train_network(config_rfa, num_epochs=100, checkpoint_interval=100)
# Out:
# Initializing Wandb:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/workspaces/RFA/RFA_Fashion/wandb/run-20260313_140351-4</code>
# Resuming run <strong><a href='https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000/runs/4' target="_blank">FC_Model1_RFA</a></strong> to <a href='https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000' target="_blank">https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000</a>
#  View run at <a href='https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000/runs/4' target="_blank">https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000/runs/4</a>
# Collected 30 images for visualization (3 from each of 10 classes).
# Resuming from previous run...
# Best Val Acc so far in the training run: 85.7
# EPOCH:  301
# Time:  2.541123628616333
# EPOCH:  302
# ...
