# %%
import torch
import config as c
from utils import trainer as t
# Out:
# Current Path: /workspaces/RFA

# %%
config = c.get_config(0, run_id="1")
config_rfa = c.get_config(1, run_id="2")

# %%
t.train_network(config, num_epochs=300, checkpoint_interval=100)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# Initializing Wandb:
# wandb: Currently logged in as: g-aravindadithya (Trainers100) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/workspaces/RFA/RFA_Fashion/wandb/run-20260308_203838-1</code>
# Syncing run <strong><a href='https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000/runs/1' target="_blank">FC_Model1_Relu</a></strong> to <a href='https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000' target="_blank">https://wandb.ai/RFA100/FashionMNIST_RFA_seed_1000</a>
# ...
